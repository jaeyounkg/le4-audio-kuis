# %%
import audioop
import math
import pickle
import sys
from functools import reduce

import librosa
import matplotlib.pyplot as plt
import numpy as np
import pyaudio
import scipy.io.wavfile
from playsound import playsound

# %%
x, sr = librosa.load("data/output_ref.wav")
plt.plot(x)

# %%
sr
# Out:
# 22050

# %% [markdown]
# # Concat wav outputs

# %%
xs = []
for i in range(1, 270):
    x, _ = librosa.load(f"tmp/recorded{i}.wav")
    xs.append(x)

# %%
plt.plot(np.concatenate(xs[100:102]))

# %%
plt.plot(np.concatenate(xs[100:105]))

# %%
plt.plot(np.concatenate(xs))
